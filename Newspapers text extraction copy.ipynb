# %%
import os
import pandas as pd
import xml.etree.ElementTree as ET
from tqdm import tqdm
from datetime import datetime

# %% [markdown]
# **Load the newspapers**

# %%
base_path = r'\\ent1files.epfl.ch\ElyseeMuseum\PROJECT_DATA\BCU_v2\RawData_newspaper\LLE_temp'
data = []

nb_news_tot = 0
nb_news = 0

def parse_alto_xml(file_path):
    text = ""
    tree = ET.parse(file_path)
    root = tree.getroot()
    ns = {'alto': 'http://schema.ccs-gmbh.com/ALTO'}
    for text_block in root.findall('.//alto:TextBlock', ns):
        for text_line in text_block.findall('.//alto:TextLine', ns):
            for string in text_line.findall('.//alto:String', ns):
                text += string.attrib['CONTENT'] + ' '
            text += '\n'
    return text

# Iterate over directories and use tqdm to show the progress.
for newspaper_dir in tqdm(next(os.walk(base_path))[1], desc="Processing Newspapers"):
    alto_dir = os.path.join(base_path, newspaper_dir, "ALTO")
    newspaper_text = ""
    nb_news_tot += 1
    if nb_news == 5: 
        break
    if os.path.exists(alto_dir):
        nb_news += 1
        alto_files = os.listdir(alto_dir)
        # Wrap the list of ALTO files with tqdm to show progress for each newspaper directory.
        for alto_file in tqdm(alto_files, desc=f"Processing {newspaper_dir}"):
            if alto_file.endswith(".xml"):
                alto_file_path = os.path.join(alto_dir, alto_file)
                newspaper_text += parse_alto_xml(alto_file_path) + "\n\n"
        data.append({"newspaper_name": newspaper_dir, "content": newspaper_text})
    else:
        print(f"ALTO directory not found for {newspaper_dir}")

newspapers = pd.DataFrame(data)
# Out:
# Processing 19571025_01: 100%|██████████| 24/24 [00:01<00:00, 12.70it/s]
# Processing 19330526_01: 100%|██████████| 12/12 [00:00<00:00, 19.04it/s]t]
# Processing 19330527_01: 100%|██████████| 12/12 [00:00<00:00, 17.19it/s]
# Processing 19330529_01: 100%|██████████| 10/10 [00:00<00:00, 17.12it/s]
# Processing 19330530_01: 100%|██████████| 10/10 [00:00<00:00, 39.12it/s]
# Processing Newspapers:   0%|          | 5/2102 [00:04<29:54,  1.17it/s]

# %%
newspapers.to_csv(r'\Users\kenji\OneDrive\Documents\EPFL\Master Project\newspaper_df.csv', index=False)

# %%
newspapers = pd.read_csv(r'\Users\kenji\OneDrive\Documents\EPFL\Master Project\newspaper_df.csv')

# %%
newspapers.head(5)
# Out:
#   newspaper_name                                            content
# 0    19571025_01  Nouvelles du iour \nTournee decisive en France...
# 1    19330526_01  R 1 : DACTIONET \nADMINISTRATION \nas . Avenue...
# 2    19330527_01  NOUVELLESDUJOUR \nM . Rooseveltaprononcéladéva...
# 3    19330529_01  NOUVELLESDUJOUR \nLescontribuablesparisiensenI...
# 4    19330530_01  · SQ . l 1 ver \n· le \n· la \n\n\n· Altesse \...

# %% [markdown]
# **Functions to Process newspapers**

# %%
from nltk.tokenize import word_tokenize
import re

# Function to parse and format the date
def parse_date(name):
    date_str = name.split('_')[0]  # Extracts the date part (AAAAMMDD)
    date_obj = datetime.strptime(date_str, '%Y%m%d')  # Parses the date
    return date_obj.strftime('%Y-%m-%d')  # Formats the date as YYYY-MM-DD




# Function to remove numbers, punctuation, and tokenize
def preprocess_and_tokenize(text):
    # Remove numbers
    text_no_numbers = re.sub(r'\d+', '', text)
    # Remove punctuation
    text_no_punctuation = re.sub(r'[^\w\s]', '', text_no_numbers)
    # Tokenize
    tokens = word_tokenize(text_no_punctuation)
    return tokens


#Function to check how many of those words appears at least once in the newspaper
def fribourg_score(content):
    to_check = ["Fribourg", "fribourg", "fribourgeois", "fribourgeoise"]
    score = 0
    for word in to_check:
        if word in content:
            score += 1
    return score

# %%
newspapers['date'] = newspapers['newspaper_name'].apply(parse_date)
newspapers['tokenized_content'] = newspapers['content'].apply(preprocess_and_tokenize)
newspapers["num"] = newspapers["newspaper_name"]
newspapers = newspapers[["num", "date", "content", "tokenized_content"]]
newspapers["length"] = newspapers["tokenized_content"].apply(len)
newspapers["score"] = newspapers.tokenized_content.apply(fribourg_score)

# %%
newspapers.head()
# Out:
#            num        date                                            content  \
# 0  19571025_01  1957-10-25  Nouvelles du iour \nTournee decisive en France...
# 1  19330526_01  1933-05-26  R 1 : DACTIONET \nADMINISTRATION \nas . Avenue...
# 2  19330527_01  1933-05-27  NOUVELLESDUJOUR \nM . Rooseveltaprononcéladéva...
# 3  19330529_01  1933-05-29  NOUVELLESDUJOUR \nLescontribuablesparisiensenI...
# 4  19330530_01  1933-05-30  · SQ . l 1 ver \n· le \n· la \n\n\n· Altesse \...
#
#                                    tokenized_content  length  score
# 0  [Nouvelles, du, iour, Tournee, decisive, en, F...   31859      3
# 1  [R, DACTIONET, ADMINISTRATION, as, Avenue, deP...   10708      2
# 2  [NOUVELLESDUJOUR, M, Rooseveltaprononcéladéval...   11347      3
# 3  [NOUVELLESDUJOUR, LescontribuablesparisiensenI...    8147      1
# 4  [SQ, l, ver, le, la, Altesse, lieu, choeur, dh...     969      2

# %% [markdown]
# **Part to select passages that contains words related to fribourg**

# %%
import textwrap

def print_list(passage, width=80):
    wrapper = textwrap.TextWrapper(width=width)
    
    formatted_passage = ' '.join(passage)
    wrapped_passage = wrapper.fill(text=formatted_passage)
    print(wrapped_passage)
    print("\n---\n")

def print_text(text, width=80):
    wrapper = textwrap.TextWrapper(width=width)
    wrapped_passage = wrapper.fill(text=text)
    print(wrapped_passage)
    print("\n---\n")

def cut_content(content, cut_size):
    """
    Selects only the relevant parts of the content that contains specific words related to Fribourg.
    Args:
    - content: tokenized list of words of the newspaper.
    - cut_size: the number of words to cut from around the specific word.

    Returns:
    - cutted: a list of cut parts from the newspapers containing around the specific word.
    """
    to_check = ["Fribourg", "fribourg", "fribourgeois", "fribourgeoise"]
    cutted = []

    max_size = len(content)
    to_cut = int(cut_size / 2)
    last_cut_end = 0  # Track the end position of the last cut

    for i, word in enumerate(content):
        if word in to_check:
            start_pos = max(0, i - to_cut)
            end_pos = min(max_size, i + to_cut)

            # If the start position is within the range of the last cut, adjust it to prevent overlap
            if start_pos < last_cut_end:
                # Adjust start_pos to last_cut_end and end_pos accordingly, ensuring it doesn't exceed max_size
                start_pos = last_cut_end
                end_pos = min(max_size, start_pos + cut_size)

            # Update the last cut's end position
            last_cut_end = end_pos

            # Cut around the word, making sure we don't exceed the size of content
            temp_cut = content[start_pos:end_pos]
            if len(temp_cut)>0:
                cutted.append(temp_cut)

    return cutted

# %%
interesting_cut = newspapers.tokenized_content.apply(cut_content, args = (100,))

# %%
for passage in interesting_cut[1]:
    print_list(passage)
# Out:
# tIlon eccestastìque aitetc eattuetaccepte es quatre organisateurs ontchoisi
# lefutur évêquedelEgliseprotestante unifiéedAlle CestlepasteurFrédéric vonBodel
# hwi h di BlfId Wt descwmg qUi Ingea leee en es l d unegraneinstitution deblenfal
# fd d d n eelar s np ele ou sce tames demaaes impoents etdedevoyessontducantonde
# hébergés M vonBodelschwingh estâgé SIXans ANNONCES PUBLICITASS A Fribourg
# RuedeBlimont Téléphone PRIX DESANNONCES Lemillimètresurunecolonne Canton Ysct
# SuisseIOct Etranger t ct Réel ct CHINEETJAPON Tokio mai Leporteparole
# duministère delaguerre démentlesinformations annonçant laconclu
# siondunarmisticesinejaponais Nankin mai Leporteparole dugouvernement commen
# tantlanouvelleducompromis sinejaponais dl dans lenord aecaréque commePékinet f
# TienTsinétalentmenaces l aallucalmerla population maiscelàne
# gouvernementaconcluouseproposedecon apocheclureuncompromisavecleJapon Tokio mai
# Laccordslnojaponaisdevaitêtresignéhier Ilauraituncaractèrepréliminaire On
# sattendàcequilaboutisseàlaconclusion
#
# ---
#
# leSimplon leSplügen leWeis senstein lYbergeregg LaFurka etleGrimsel
# serontouvertsaudébutdejuin Sontpraticahles enFrance Aravis Bayard Cabre Granier
# Gets MontCenis MontGenèvre Lautaret coldePorte coldeVars route dhiver dl Alpes
# ET LESSPORTS Avantleschampionnats dumondedetir LeBuruladonnélalistesuivante
# destireurs quidéfendront prochainement lescouleurs suis ses
# auxchampionnaisdumonde àGrenade mètres Zimmermann Hartmann De mierre Tellenbach
# Salzrnnnn GeigerelReich mètres pistolet Crivelli Schnyder Bullo Fribourg Andres
# Ftückiger Schaffner MorfetZulauf Verslafioduchampionnat suissedefootball
# Deuxmatches irnportauts sedisputeront le mai lafinaleduchallenge national entre
# YoungBoys etGrasshoppers quisejouera à Berne etlematchBâleServette quiauralieu
# àBâle Levainqueur decedernier matchdispulera lesfinalesduchampionnai encompagnie
# de Grasshoppers deYoungFelluws etdeBerne Rappelons
# quelesGenevoisavaientétédésignés parlesortpourdisputersurleurterrainlematch
# dappui contre YoungBoys elquelecomité central exigeaquilsallassent combattre
# àLau sanne Cellefois lesarlestnettement contraire àServette Lereprésentant
# delaSuisseromande
#
# ---
#
# à voix dAntonin Bruckner ainsi quunAveMaria dumêmeauteu estlàune
# précieuseaubaine ettousleshabitues denotre grandmessecapitulaire seréjouiront
# dentendre lesproductions liturgiq es delaf orissa te C ci liennedesbordsdelAar
# dont laréputation artistique nestplusàfaire Lorgue sera tenu parM Dobler
# LaSociétéseraensuite lobjet dunepetiteréception parlechoeur mixte de
# SaintNicolas dontelleestmembre honoraire depuissapremière vi iteàFribourg en
# Aprèsunbanquet qUIseraserviaurestaura t desMerciers ellequittera Fribourg par
# train spécialpour serendreàMoral doùellerega gneraBernedanslasoirée
# Lesétroitesrelations quiunissent notrepopu lationànoscoreligionnaires
# delavillefédérale garantissent àlaCécìliennedelaparoissedela SainteTrinité
# laccueil lepluscordial dansno trecité Vols Onnousécrit
# Danslanuitdemardiàmercredi descam brioleurs sont entrés pareffraction dans des
# garesduBulleRomont ilSalesetàVaulruzct danscettedernière ontemportéunesommedun
# peuplusdecentcinquante francs tII LapolicedeSûretédeBullearéussiàdécou
# vrirdansungarçondetreizeans delarégion duGibloux lauteur denombreux volsdevélos
# Quatredeceuxciontétéretrouvés uollisiuu Hier après midi jeudi vers
#
# ---
#
# heures à Fribourg surlaplacedelagare unecollision sestproduite
# entreunemotocyclette conduite parM AntoineHuber coiffeur etlautomobile deM Jenny
# boucher Lemotocycliste aété légèrement blessé Lesdeuxmachines ontsubi
# guelquesdégâts Uncalculintéressant àproposdestraitementsfédéraux Onnousécrit
# Jesuisétonné quaucun journal naitpensé àJoccasion delavotation du mai àétablir
# lecapital quilfuudraitconstituer pourpayer lesfonctionnaires fédéraux Cecalcul
# cependant nemanquerait pasdintérêt Lamoyenne destraitements estde fr auxquels
# ilfaut ajouter linsupplément de Irpourfraisdassurance duniforme de déplacements
# etautres Lefonctionnaire coûte donc enmoyenne fr àlaConfédération Pourproduire
# celtesomme ilfautuncapital de fr placéau etmêmedavan tage puisquelecréancier
# quidéposesonargent enobligations dansunebanque doitpayerun droitdetimbrede fr
# parmilleparanet unimpôtsurlescoupons de Or dansnoscampagnes etdansnospetites
# villes unhomme quipossède fr passe pourunhomme riche Ilneviendrait àpel
# sonneTidée dele plaindre Aprèscela diraton quenosfonctionnaires
# ontdestraitements
#
# ---
#
# h Cardinal contreles Entreprises électriques Onpanrraassisteràdeux
# bellesrencontres carleséquipessetiennent de près Samedi maionteùlieudeuxmatches
# dé championnat VillarsetWinckler ontfaitmatch nul par butà LesEntreprises
# électriques ont battu Sarinapar butsàO Villarset Winckler possèdent
# debelleséquipesquiferont encoreparlerdellesaucoursduchampionnat LesEntreprises
# électriquesse sontprésentées avecplusieurs remplaçants Lesamateurs
# defootballquivoudraient passel unagréable samedi aprèsmidiserendront au
# stadedelaMottaz pourencourager lefootball corporatif Lesrésultats
# serontaffichésaulocaldesclubs corporaurs aucafédesAlpes Fribourg Bainsdela
# LUottaz Lassemblée desactionnaires delaSociétédes bainsdelaì
# Iottazadécidéladistribution dlm dividende de auxaclions privilégiées Betou
# defroid sensihlement fraîchi La température a jourdelAscension Lanuitdernière il
# pentesduCousìmbert aneigéfortbassurles le LéglisetleSomlllcnticr Onnousécrit
# Lassemblée communale de Sommentier a adjugé laconstruction dell glise delafuture
# paroisse encequiconcerne lamnconneric aux entrepreneurs Mauron de Vrllarnboud et
# Masser deVaulruz encequi
#
# ---
#
# SLUleshauteurs dArconciel lestireurs venus de touteslespartiesdudistrict
# Duplateau où lescarabiniers dArconciel ontconstruit unstand simple
# maisfortbienaménagé lavuesélen dtlit surunpaysage splendide Lorganisation
# irréprochable desconcours per Oitdétablir rapidement leclassement desso ciétés A
# h avaitlieulaproclamation desrésul t ts danslasalledelauberge communale Le
# comité delaFédération yavaitinvitéM Renevey p éfet etM ledocteur Comte président
# dela société cantonale destireurs fribourgeois La Population du
# villageetdesenvirons syétait donné rendezvous etfaisaitauxtireurslaplus ajmable
# réception Leprésident delaFédération M LouisDu praz félicita tout dabord
# lecomité cantonal d avoirchoisiunedatesiprintanière pourles tirs etdavoir ainsi
# fait queleconcours se déroulât parunemagnifique journée Ilconstata que malgré
# lepeudentraînement nombre detireursnayant pasmêmefaitleurtirobliga toire
# lesrésultatsdetouteslessociétésétaient remarquables _ Laraisonenestque
# siletirest aj fairedentraînement ilestplusencoreeffort ccéJl
#
# ---
#
# SociétédetirdeVuisternensenOgoz Touteslessociétésontobtenulacouronne de laurier
# quiétaitdélivréepourunemoyenne de points Pistolet mètres
# SociétédetiraupistoletdelaSarine sous officiers pistolet couronne delaurier _
# Lacouronne delaurierétaitdélivréepourune moyenne de points Résultatsindividuels
# Ciaprès lesmeilleurs résultats individuels Fusil mètres points ClémentHobert
# FribourgMilitaire p Jordan Robert FribourgVille p Brohy Léon FribourgMilitaire
# Bul liardMarius Rossens Castelberg Walter Grau willer Hans Widmer Walter jun
# Fribourg Ville p Corboud Alfred Ruffieux Louis Fri bourgVille p Brülhardt
# Auguste BullaFlorian Fri bourgVille Ridoux Fortuné Winiger Joseph
# CorsereyLentigny p BarrasJoseph Belfaux DausseMax Arconciel EggerFrançois
# FreyJoseph Gerber Jacques FribourgMilitaire Hoering Fernand FribourgVille
# MorelJules LentignyCorserey Philipona Gérard Treyvaux Stucky Auguste Fribourgv u
# p BoschungAlfred Belfaux DrouxRaoul VuìsternensenOgoz GuhlMarcel FribourgVille
# Paffetlouis
#
# ---
#
# SlempfelJoseph FribourgMilitaire Wittwer Frédéric FribourgVille p Brechbühl Em e
# FribourgMilitaire Chatagny Marcel LentìgnyCorserey DeDiesbach Roch Marly
# Descloux André Rossens Frey Jean FribourgMilitaire KupperEmile Fribourg Ville
# Oberson Charles FribourgMilitaire Pas quierIgnace Treyvaux Python Maxime Arcon
# ciel SuterEugène Widmer Edouard Wolhauser Franz FribourgVille p Andrist Fritz
# FribourgVille Bifrare Martin FribourgVille Bongard Joseph Marly BordAimé Rossens
# Boschung Gabriel Rossens Corpataux Albin FribourgMilitaire Ducrest Ar sène
# Rossens Ducrest Eugène Vuisternensen Ogoz DucrestJoseph Marly DuprazLouis
# FribourgVille _ HaferOtto FribourgVille Python Séraphin ArconcieC r Rlvil
# deorgés Fribourg Ville RoulinConrad Treyvaux Scheurer Arnold Arconciel Thurler
# Auguste FrìbourgMilitaire Vonlanthen Alfred Rossens Widmer Walter sen
# FribourgVille WolfPaul FribourgVille VerlyJoseph
#
# ---
#
# Treyvaux p Ammann Arnold FribourgVille Biel mann Joseph Marly Brugger Alphonse
# Marly Clément Robert Belfuux DausseJoseph Arcon ciel LimatHenri FribourgVille
# Marchon Phi lippe FribourgMilitaire MoulinPierre Fribourg Militaire
# NicoletMarcel Belfaux Paradis Jean Treyvaux ProbstWalter FribourgMilitaire Sei
# bozLouis Treyvaux Sciboz Pierre Treyvaux Wolhauser Louis FribourgVille Pistolet
# mètres LucienOchsenbein Fribourg points Flo rianBullo id Fernand Hoerìng id
# FritzAndrist id AlfredLehner ld OttovonDach id Statistiqueélectorale
# Voicilétatdesélecteurs delaville bourgpourlavotation du mai Places
# PérellesBeauregard Bourg Neuveville Auge deFri Lesdeuxsecteurs
# desPlacesetdePérolles Beauregard tendent àprendre desproportions excessives En
# quandonétablitladivisionactuelle encréantlesecteurPérellesBeauregard lesec
# teurdesPlaces quifutjugéexagérément étendu létaitmoinsquemaintenant
# Ilnyavaitalors quenviron électeurs dans toute laville haute Lemoment semble venu
# desonger àun remaniement
#
# ---
#
# des secteurs desPlaces elde PérollesBeauregard Ilparaît indiqué decons
# tituerunnouveau secteur BeauregardGamhach cequiallégerait lesdeux immenses
# secteurs actuels Nosmaeona Afin de classer officiellement notre main doeuvre
# touslesouvriers dubâtiment quiesti mentêtredevéritables maçons sontinvités à
# sinscrire audépartement dellndustrie etdu commerce chancellerie
# Alasuitedenquêtes eldexamens éventuels uncertificat seradélivré afindepermettre
# une sérieuseclassification desouvriers quisedisent maçons Celteinscription
# doitsefairediciau juin AdjIl lications Lestravaux deferblanterie delhôteldeFri
# bourgontété adjugés à lM LouisDaguet filsetCharlesOrllieb ferblantiers àFribourg
# Lethéâtre lacampagne Onnousécrit LethéâtredeTreyvaux vafaireunefoisde
# plushonneur àsatradition Lesjeunes filles dugroupeparoissial
# lAururevontprésenter les dimanches maiet juin deux excellentes pièces Lapremière
# estundramepathétique de lécrivain breton bienconnu HenéGaël Letitre
# Plusfortquelahainelaissedeviner lahaute portéemoralequisen dégag Ilatìeinlàune
# admirable profondeur desentiments ettraduit lesaspirations
#
# ---
#
# dun noble stoicistue chrétien Maisilyaunedouceforcepluspuissanteque lahaine
# NOliSapprenons sonnomtrèsnoble audénouement Quittant lesbrumesdelArmorique
# nousnous transportons ensuite danslapleinelumièredu Midi LafoiredeSéville dlCh
# LeRoyVillars faitdanser leboléroetlebalgonguo surune placerutilante desuleil
# Toutypétilledecette effervescence des Méridionuux Lentrain ia gaieté leschants
# enveloppent làbusleschoses lesplusgraves Cenest certes pasauMtri mentdeladignité
# Tout yrespire labonne humeur etceseradeuxactesdefourire Ajoutons
# quelesdeuxpiècesserontdorinées parde actrices hahilement styléesetaumilieu
# dedécorsentièremenl remisilneuf Lespectacle adernun Ié lecoucoursdenomhreuses
# bonnes volontés Elles attendenl denêtrepayéespar uneaffluence particulièrcrnent
# nombreuse àcès bellesséances Voirauxannonces Hcimatschntz
# Cestavecungrandplaisirquenousapprenons quecetteannéelassemblée générale duHei
# matschulz suisseauralieuenSuisseromande On seréunira lesamedi lOjuin àPayerne
# pour lassemblée desdélégués dimanche Iljuin Qn visiteraEstavayer où lM Taverney
# deLausanne etMatthey deNeuchâtel traiteront lagrave question delaprotection
# desrivesdenoslacs Lenouveau cahierdelarevue quiesttouten
#
# ---
#
# CHARLEN p Bulle Jeunefilleconnaissant leservicede sommelière etfilledesalle
# chercheplace ouéven Iilellenientdansmagasin pourtoutdesuileou dateàconvenir
# SadresseràPublicitas rille souap B Avendre danslaGlâne domaine de JI
# posesenunseul mas dont Y boiset verger Terrainde requa lité vasteetbeaubâti ment
# Porcherie creuxà purin pontdedécharge tousaccessoires Offres sousNo casepostale
# Fri bourg Ondemandeun orteur e ain Sadr sousp F àPublicites Fribourg AVENDRE
# fautedemploi uncamion de tonnes prixavanta ge dresser àPublicitas BULLE sousP B
# à _ prixtrès a yantag ul pianousagé enbonétat conviendrait pourétude
# oucaférestaurant Sadresser àPublicites Fribourg sous chiijrcs P F Jeunebomme
# pastrèsrobuste demande placecommeaidejardi nier conciergeouautre occupation
# irait aussi chezpetit agriculteur Sadressersalischiffres P F àPublicites
# Epicerie avechab tationetjardin AVENDRE
#
# ---
#
# àlacampagne Bonren dement Sadr àA Frossard agence immobilière Fri bourg
# Grandchoixdetoutes provenances Tél MOUDON ImorlmerieSI PaUI Impressions
# entousgenres CANALS Vins Jeunefille Bureaudetransportsct voyagesdelaplacede
# mande Apprenti françaisetallemandexi gés Entréetoutdesuite ouàconvenir Seprés
# oufaireoffres àlamaison LangGuyer PlacedelaGare Fri bourg Alouer logementde
# chambres cuisineetjardin Sadr J Broille Be faux Chauffeur Jeunehomme ans
# demandeplacedansIa milleouégalement dans commercecommelivreur
# Référencesàdisposition Sadressersouschiffres P P àPublicites Fribourg sérieuse
# demandée dans maison soignée comme bonne àtoutfaire Offresavecréférences
# àMmeBurnier LeBruan Chemin Mon Olive Lau sanne pièces balcons luut confort
# Ìllixmod r Sadresser fpl illc du Midi Ti l n elage Oudemande Jeunefille
# pouraiderauménage t tacampagne ïeder ì milleclbonssoinsassurés Sadresser chez
# Louis
#
# ---
#
# Herren lugnowr non Voud ti ti Jo JEUNEHOMME counaissnnt toustravuux debureau
# elposstduur permis deconduire cher cheoccupuìiou acccssouc pourlesoir
# soittenuede cornptalrilité ctlru auxde toutgenre snitcourses avecautomobile
# SadresserSOllSchiffns p i F tiPuìrlicitas Fribourq AVENDRE plusieursvaches valai
# sannes bonneslaitières chezA DROMPT au Pré delaJoux Le PAquier Il AVENDRE
# unejeune belletruie portante de xcmuirux menichée ï Sudr ìPierreScliôpicr
# PrezversN oréo AlOUER aucentredelaville pilit logement dunechambrellcuisine
# avecdépendnnces SadresserSOllSehiffrt S P F ùPubticitu Fribourg Bel appartement
# Ondemandeunebonne Sommelière detouteconfiance de à ans Sadr sousP F àPublicitas
# Fribourg ALOUER appartementde cham bres cuisineetdépen dances Bienexposéau
# soleil Sadresser Grand Rue No rez dechaussée à gauche IDICHEUn pourbicyclettes
# Le
#
# ---
#
# PneuFr Lachambreàair Fr Eichenbergerfrères s A VisfivisdesArcadesde làgare
# Fribourg Envoiscontrerembour sement Mélange l meilleurdei TABACS Ii CI lIB
# IlIYmBR ZURICH OndenlBude unouvrier boulanger pâtissier detoutecon
# fianceetpouvanttravail erseul Entréeimmédiate SadresserilMmeveuve RaymondBrascij
# boulon geriepâtisserie Estavayer leLpc LOOÂTION deJ MachineS rire Papetertè J
# LABASTROU ruedeLausanne FRmOURG ALOUER pourle juillelcou rant dansvillatrèsen
# soleillée au Gambach unJol LO iDlENTde fipiècesaY CC confort moderne Prixmodérés
# Sadr sousP F àPubIleIlas Fribourg Aremettre IO excellente entreprise commeretale
# debon rapport trav agréà blepourmonsieur ou dame Cap néces saireIFr
# Ecriresouschiffres D X àPubll citas Genève
#
# ---

# %%
avg_nb_passage = int(sum(len(interesting_cut[i]) for i in range (len(interesting_cut)))/len(interesting_cut))
nb_tokens = int(sum(len(interesting_cut[i][j]) for i in range (len(interesting_cut)) for j in range(len(interesting_cut[i]))))
print(f"Nb newspaper having interesting word: {len(interesting_cut)} ~ {(len(interesting_cut)/nb_news)*100}%")
print(f"Average number of interesting passage per newspaper: {avg_nb_passage}")
print(f"Total number of tokens retains: {nb_tokens}")
print(f"Average number of tokens retains per newspaper: {int(nb_tokens/len(interesting_cut))}")
# Out:
# Nb newspaper having interesting word: 5 ~ 100.0%
# Average number of interesting passage per newspaper: 22
# Total number of tokens retains: 10887
# Average number of tokens retains per newspaper: 2177

# %% [markdown]
# **Save passages**

# %%
import pickle


# Save with pickle
with open('interesting_cut.pkl', 'wb') as f:
    pickle.dump(interesting_cut, f)

with open('interesting_cut.pkl', 'rb') as f:
    loaded_interesting_cut = pickle.load(f)

# %% [markdown]
# **OPENAI text correction**

# %%
import openai
from openai import OpenAI

# %%
client = OpenAI(api_key='YOUR_PRIVATE_KEY')

# %%
# La liste des mots ou phrases à nettoyer et réécrire
list_to_process = loaded_interesting_cut[1][0] # premier passage du second journal


# Convertir la liste en une chaîne de caractères formatée pour la requête
text_to_process = " ".join(list_to_process)

print(len(list_to_process))
print_text(text_to_process)
# Out:
# 100
# tIlon eccestastìque aitetc eattuetaccepte es quatre organisateurs ontchoisi
# lefutur évêquedelEgliseprotestante unifiéedAlle CestlepasteurFrédéric vonBodel
# hwi h di BlfId Wt descwmg qUi Ingea leee en es l d unegraneinstitution deblenfal
# fd d d n eelar s np ele ou sce tames demaaes impoents etdedevoyessontducantonde
# hébergés M vonBodelschwingh estâgé SIXans ANNONCES PUBLICITASS A Fribourg
# RuedeBlimont Téléphone PRIX DESANNONCES Lemillimètresurunecolonne Canton Ysct
# SuisseIOct Etranger t ct Réel ct CHINEETJAPON Tokio mai Leporteparole
# duministère delaguerre démentlesinformations annonçant laconclu
# siondunarmisticesinejaponais Nankin mai Leporteparole dugouvernement commen
# tantlanouvelleducompromis sinejaponais dl dans lenord aecaréque commePékinet f
# TienTsinétalentmenaces l aallucalmerla population maiscelàne
# gouvernementaconcluouseproposedecon apocheclureuncompromisavecleJapon Tokio mai
# Laccordslnojaponaisdevaitêtresignéhier Ilauraituncaractèrepréliminaire On
# sattendàcequilaboutisseàlaconclusion
#
# ---

# %%
response = client.chat.completions.create(
  model="gpt-3.5-turbo",
  messages=[
        {
            "role": "system",
            "content": "Vous êtes un assistant très intelligent chargé de corriger et de réécrire les textes pour les rendre cohérents et grammaticalement corrects"
        },
        {
            "role": "user",
            "content": f"Corrigez et réécrivez ce texte en francais en utilisant tout les mots dans l'ordre: {text_to_process}"
        }

    ],
  temperature=1,
  max_tokens=300,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

# %%
print("Before processing:\n")
print_text(text_to_process)
print("After processing:\n")
print_text(response.choices[0].message.content)
# Out:
# Before processing:
#
# tIlon eccestastìque aitetc eattuetaccepte es quatre organisateurs ontchoisi
# lefutur évêquedelEgliseprotestante unifiéedAlle CestlepasteurFrédéric vonBodel
# hwi h di BlfId Wt descwmg qUi Ingea leee en es l d unegraneinstitution deblenfal
# fd d d n eelar s np ele ou sce tames demaaes impoents etdedevoyessontducantonde
# hébergés M vonBodelschwingh estâgé SIXans ANNONCES PUBLICITASS A Fribourg
# RuedeBlimont Téléphone PRIX DESANNONCES Lemillimètresurunecolonne Canton Ysct
# SuisseIOct Etranger t ct Réel ct CHINEETJAPON Tokio mai Leporteparole
# duministère delaguerre démentlesinformations annonçant laconclu
# siondunarmisticesinejaponais Nankin mai Leporteparole dugouvernement commen
# tantlanouvelleducompromis sinejaponais dl dans lenord aecaréque commePékinet f
# TienTsinétalentmenaces l aallucalmerla population maiscelàne
# gouvernementaconcluouseproposedecon apocheclureuncompromisavecleJapon Tokio mai
# Laccordslnojaponaisdevaitêtresignéhier Ilauraituncaractèrepréliminaire On
# sattendàcequilaboutisseàlaconclusion
#
# ---
#
# After processing:
#
# Les quatre organisateurs ont choisi le futur évêque de l'Église protestante
# unifiée d'Allemagne. C'est le pasteur Frédéric von Bodelschwingh qui a été
# désigné. Il est âgé de soixante ans et exerce ses fonctions à Fribourg. Il
# occupe une place importante au sein d'une grande institution bien établie. Les
# annonces publicitaires pourront être insérées dans les colonnes du journal au
# prix de dix francs suisses pour un millimètre en Suisse et à l'étranger. En
# Chine et au Japon, à Tokyo, le porte-parole du ministère de la guerre dément les
# rumeurs d'un armistice sino-japonais. À Nankin, le porte-parole du gouvernement
# déclare que les menaces dans le nord ne sont pas prises à la légère par Pékin et
# Tien-Tsin, mais qu'aucun compromis n'a été trouvé. L'accord sino-japonais
# préliminaire devait être signé hier à Tokyo. On espère que cela aboutira
# finalement à une conclusion.
#
# ---
